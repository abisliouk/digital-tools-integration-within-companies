# %% [markdown]
# # Overview

# %% [markdown]
# ## Hurdles preventing organizations worldwide from progressing with digital transformation initiatives in 2021
#
# Over half of IT professionals responding to a 2021 survey cited a lack of skills and expertise as a hurdle in achieving their digital transformation initiatives. However, a similar proportion also reported that the pandemic had hindered progress by forcing organizations to focus on maintaining their existing operations. Only around a third of respondents said that finances were preventing progress, while only eight percent said that there were no barriers to their organization realizing their digital transformation goals.
#
# Source: https://www.statista.com/statistics/1311518/factors-preventing-digital-transformation-worldwide/

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the given data
data = {
    'Hurdles': ['Lack of IT staff skills or transformational expertise', 
                'Dependencies on legacy systems and technology', 
                'Still focused on maintaining operations due to pandemic', 
                'Lack of senior management buy-in', 
                'Lack of time', 
                'Lack of money', 
                'Nothing is preventing/prevented our \norganization from moving forward with \nour digital transformation initiatives'],
    'Percentage': [54, 53, 51, 43, 39, 35, 8]
}
df = pd.DataFrame(data)

# Plot the data
plt.figure(figsize=(10, 6))
bars = plt.barh(df['Hurdles'], df['Percentage'], color='darkblue')
plt.xlabel('Percentage')
plt.title('Factors preventing digital transformation worldwide 2021')

# Add percentage values next to each bar
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{bar.get_width()}%', va='center', color='black')

plt.gca().invert_yaxis()  # Invert y-axis to have the highest value at the top
plt.show()

# %% [markdown]
# ## Organizational approaches to digital transformation worldwide in 2022, by IT solutions
#
# In 2022, the most common approaches organizations are taking to address digital transformation strategies are to reuse and repurpose existing solutions with traditional infrastructure and cloud extensions to existing solutions. This indicates that a focus on modernisation that is already in place or a mixed modernization approach is present in 45 percent of the respondents' firms. This is considerable in comparison to other, less popular strategies such internal building from scratch, which was mentioned by 15 percent.
#
# Source: https://www.statista.com/statistics/1331706/approaches-digital-transformation-it-solutions-worldwide/

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the given data
data = {
    'Approaches': ['SaaS replacement', 
                   'Build internally from scratch', 
                   'Lift and shift to the cloud', 
                   'Outsource to IT services company', 
                   'Reuse and repurpose existing solutions on-premises', 
                   'Cloud extensions to existing solutions'],
    'Percentage': [9, 15, 15, 16, 21, 24]
}
df = pd.DataFrame(data)

# Plot the data
plt.figure(figsize=(10, 6))
bars = plt.barh(df['Approaches'], df['Percentage'], color='darkblue')
plt.xlabel('Percentage')
plt.title('Approaches to digital transformation worldwide 2022, by IT solutions')

# Add percentage values next to each bar
for bar in bars:
    plt.text(bar.get_width() + 1, bar.get_y() + bar.get_height()/2, f'{bar.get_width()}%', va='center', color='black')

plt.gca().invert_yaxis()  # Invert y-axis to have the highest value at the top
plt.xlim(0, 30)  # Set the range of the x-axis from 0 to 30
plt.show()

# %% [markdown]
# # Segments

# %% [markdown]
# ## Information technology (IT) spending worldwide from 2012 to 2024, by segment (in billion U.S. dollars)
#
# The global information technology (IT) spending on devices, including PCs, tablets, mobile phones, printers, as well as data center systems, enterprise software, and communications services came to 4.7 trillion U.S. dollars in 2023. By 2024, IT spending is expected to increase to a staggering five trillion dollars worldwide.
#
#
#
#  IT services and communication services take the largest share of spending
# Both IT services and communication services receive the largest amounts of investments, as these segments include a large array of different services and tools that remain cornerstones to different business functions. For example, different unified communication services are vital to connecting employees virtually and therefore enhance business productivity.
#
#
#
#  Spending on IT segments accelerates digital transformation
# In general, spending on the different IT segments is expected to grow, accelerating digital transformation across various industries. Digital transformation encompasses the utilization of artificial intelligence , process automation, and moving data to the cloud, for example. These processes are empowered by strategic spending on and deployment of different information technologies.
#
# Source: https://www.statista.com/statistics/268938/global-it-spending-by-segment/

# %% [markdown]
# ### Information technology (IT) spending worldwide from 2012 to 2024, by segment

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the given data
data = {
    'Year': [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
    'Data Center Systems': [140, 140, 166, 171, 170, 181, 210, 215, 179, 189.51, 227.02, 236.18, 259.68],
    'Devices': [285, 300, 310, 310, 326, 369, 419, 477, 529, 732.03, 766.28, 664.03, 687.94],
    'Enterprise software': [676, 677, 649, 646, 630, 665, 712, 712, 697, 807.58, 811.31, 914.69, 1042.17],
    'IT Services': [906, 922, 897, 866, 894, 931, 993, 1040, 1071, 1207.97, 1305.70, 1385.16, 1519.93],
    'Communication Services': [1641, 1624, 1541, 1392, 1374, 1392, 1380, 1373, 1396, 1459.48, 1423.13, 1487.16, 1551.29]
}
df = pd.DataFrame(data)

# Plot the data
plt.figure(figsize=(10, 6))
for column in df.columns[1:]:
    plt.plot(df['Year'], df[column], marker='o', label=column)

plt.xlabel('Year')
plt.ylabel('Spending (in billion U.S. dollars)')
plt.title('Information technology (IT) spending worldwide from 2012 to 2024, by segment')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Cumulative IT spending worldwide from 2012 to 2024

# %%
df = pd.DataFrame(data)

# Calculate the cumulative spending per year
df['Cumulative Spending'] = df.iloc[:, 1:].sum(axis=1)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Cumulative Spending'], marker='o', color='darkblue')

plt.xlabel('Year')
plt.ylabel('Cumulative Spending (in billion U.S. dollars)')
plt.title('Cumulative IT spending worldwide from 2012 to 2024')
plt.grid(True)
plt.show()

# %% [markdown]
# # Technology Adoption

# %% [markdown]
# ## Adoption rate of emerging technologies in organizations worldwide in 2023
#
# As of 2023, nearly 92 percent of digital leaders globally stated that their companies adopted cloud technology either on small or large scale. Big data/ analytics were the second most popular adopted technology with around 61 percent of respondents reporting the same. Artificial intelligence/ machine learning
#  At the same time, 26 percent of respondents were considering using Artificial intelligence (AI) / machine learning (ML) technology, while 24 percent said that their companies were piloting the implementation AI/ML technology.
#
#
#
#
#
#  What is cloud computing?
#
# Cloud computing refers to the use of networks of remote servers accessed over the internet to store, manage, and process data. It offers customers access to a wide range of technologies while lowering costs and reducing the need for technical expertise. The cloud service market is divided into three primary service models encompassing infrastructure, platforms, and software. Customers are able to choose between private, public, or hybrid cloud deployment depending on their business needs and security concerns.
#
#
#
#
#
#  SaaS: the most widely adopted cloud solutions
#
# In line with increases in companies’ adoption of cloud computing technologies, the worldwide revenue generated from these technologies has increased rapidly in recent years. Software as a Service (SaaS) is the largest segment of the global cloud computing market with revenues forecast to be around 197 billion U.S. dollars in 2023. Popular applications of SaaS include customer relationship management and enterprise resource planning software.
#
# Source: https://www.statista.com/statistics/661164/worldwide-cio-survey-operational-priorities/

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the given data
data = {
    'Technology': ['Cloud', 'Big data/analytics', 'Internet of Things', 'Robotic process automation', 'On-demand marketplace platforms', 'Artificial Intelligence/ Machine Learning', 'Green tech', 'Edge computing', 'Blockchain/ Distributed ledger', 'Augmented/ Virtual Reality', 'Metaverse', 'Quantum computing'],
    'Have not considered': [1, 8, 40, 35, 42, 15, 40, 54, 69, 59, 74, 79],
    'Actively considering': [3, 16, 16, 17, 17, 26, 24, 16, 15, 17, 14, 11],
    'Piloting': [4, 15, 12, 14, 12, 23, 15, 11, 6, 11, 7, 5],
    'Small-scale': [24, 33, 19, 22, 19, 26, 14, 12, 8, 10, 3, 3],
    'Large-Scale': [68, 28, 13, 12, 10, 10, 7, 7, 2, 3, 2, 2]
}
df = pd.DataFrame(data)

# Plot the data
plt.figure(figsize=(10, 6))
plt.barh(df['Technology'], df['Have not considered'], color='red', label='Have not considered')
plt.barh(df['Technology'], df['Actively considering'], left=df['Have not considered'], color='orange', label='Actively considering')
plt.barh(df['Technology'], df['Piloting'], left=df['Have not considered'] + df['Actively considering'], color='yellow', label='Piloting')
plt.barh(df['Technology'], df['Small-scale'], left=df['Have not considered'] + df['Actively considering'] + df['Piloting'], color='green', label='Small-scale')
plt.barh(df['Technology'], df['Large-Scale'], left=df['Have not considered'] + df['Actively considering'] + df['Piloting'] + df['Small-scale'], color='blue', label='Large-Scale')

plt.xlabel('Percentage')
plt.title('Adoption rate of emerging technologies in organizations worldwide in 2023')
plt.legend()
plt.gca().invert_yaxis()  # Invert y-axis to have the highest value at the top
plt.show()

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a DataFrame from the given data
data = {
    'Technology': ['Cloud', 'Big data/analytics', 'Internet of Things', 'Robotic process automation', 'On-demand marketplace platforms', 'Artificial Intelligence/ Machine Learning', 'Green tech', 'Edge computing', 'Blockchain/ Distributed ledger', 'Augmented/ Virtual Reality', 'Metaverse', 'Quantum computing'],
    'Have not considered': [1, 8, 40, 35, 42, 15, 40, 54, 69, 59, 74, 79],
    'Actively considering': [3, 16, 16, 17, 17, 26, 24, 16, 15, 17, 14, 11],
    'Piloting': [4, 15, 12, 14, 12, 23, 15, 11, 6, 11, 7, 5],
    'Small-scale': [24, 33, 19, 22, 19, 26, 14, 12, 8, 10, 3, 3],
    'Large-Scale': [68, 28, 13, 12, 10, 10, 7, 7, 2, 3, 2, 2]
}
df = pd.DataFrame(data)

# Plot the data
plt.figure(figsize=(10, 6))
categories = ['Have not considered', 'Actively considering', 'Piloting', 'Small-scale', 'Large-Scale']
colors = ['black', 'orange', 'gray', 'green', 'blue']
left = np.zeros(len(df['Technology']))

for idx, category in enumerate(categories):
    plt.barh(df['Technology'], df[category], color=colors[idx], left=left, label=category)
    for i, value in enumerate(df[category]):
        if value > 0:
            plt.text(value/2 + left[i], i, str(value) + '%', va='center', ha='center', color='white', fontweight='bold')
    left += df[category]

plt.xlabel('Percentage')
plt.title('Adoption rate of emerging technologies in organizations worldwide in 2023')
plt.legend()
plt.gca().invert_yaxis()  # Invert y-axis to have the highest value at the top
plt.show()

# %% [markdown]
# ## Artificial intelligence (AI) adoption worldwide 2022, by industry and function
#
# Artificial intelligence (AI) is heavily used for service operations and strategy and corporate finance, with nearly all industries reporting around 20 percent usage of AI in these functions. The greatest use of AI in product making was in the risk industry, with over 38 percent of respondents using AI in 2022. The use of AI in manufacturing and marketing is low, as these can require individual human instincts and so lend themselves less easily to AI applications.
#
#
#
#  AI adoption isn’t easy
#
# It is no easy task to adapt a new technology of such widespread use as AI. There are numerous pitfalls and problems, both from the use of the technology itself but also from actions by outside agents causing issues. Companies considered cybersecurity to be chief among the risks being mitigated when adapting AI in 2023. In addition, regulatory compliance was a considerable challenge, stemming from a strong need to respect information privacy among users.
#
#
#
#  Employment faces steep headwinds
#
# AI will have a considerable effect on the labor needs of nations worldwide. Of the many professions, office and administrative support are facing the greatest risk of automation. These are linear and formulaic positions, with many of their duties delegable to advanced programs.
#
# Source: https://www.statista.com/statistics/1112982/ai-adoption-worldwide-industry-function/

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a DataFrame from the given data
data = {
    'Department': ['Human resources', 'Manufacturing', 'Marketing & sales', 'Product/service development', 'Risk', 'Service operations', 'Strategy & corporate finance', 'Supply chain management'],
    'All industries': [11, 8, 5, 10, 19, 19, 21, 9],
    'Business, legal, and professional services': [11, 10, 9, 8, 16, 20, 19, 12],
    'Consumer goods/retail': [14, 4, 3, 4, 15, 31, 29, 11],
    'Financial services': [1, 8, 7, 31, 17, 24, 23, 2],
    'Healthcare/pharma': [15, 7, 2, 4, 22, 12, 8, 8],
    'High tech/telecom': [6, 6, 4, 7, 38, 21, 25, 8]
}
df = pd.DataFrame(data).set_index('Department').T

# Plot the data
plt.figure(figsize=(10, 6))
departments = df.columns
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'purple', 'pink', 'brown']
bottom = np.zeros(len(df))

for idx, department in enumerate(departments):
    plt.bar(df.index, df[department], color=colors[idx], bottom=bottom, label=department)
    for i, value in enumerate(df[department]):
        if value > 0:
            plt.text(i, value/2 + bottom[i], str(value) + '%', va='center', ha='center', color='white')
    bottom += df[department]

plt.ylabel('Percentage')
plt.title('Percentage distribution of departments in different industries')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.show()
